# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv('srdata.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
df.drop(columns=['Respondent'], inplace=True)

# %%
df
# Out:
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 88878                                                NaN      Yes
# 88879                                                NaN       No
# 88880                                                NaN       No
# 88881                                                NaN       No
# 88882                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  ...  \
# 0      Taught yourself a new language, framework, or ...  ...
# 1      Taken an online course in programming or softw...  ...
# 2      Taught yourself a new language, framework, or ...  ...
# 3      Taken an online course in programming or softw...  ...
# 4      Taken an online course in programming or softw...  ...
# ...                                                  ...  ...
# 88878  Taught yourself a new language, framework, or ...  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Taken an online course in programming or softw...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 84 columns]

# %%
df.duplicated ()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879     True
# 88880     True
# 88881     True
# 88882    False
# Length: 88883, dtype: bool

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# MainBranch        447
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2015
# Employment       1678
#                 ...
# Sexuality       12631
# Ethnicity       12110
# Dependents       5719
# SurveyLength     1794
# SurveyEase       1697
# Length: 84, dtype: int64

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.dtypes
# Out:
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
# Employment      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 84, dtype: object

# %%
df.isnull().any()
# Out:
# MainBranch      False
# Hobbyist        False
# OpenSourcer     False
# OpenSource      False
# Employment      False
#                 ...
# Sexuality       False
# Ethnicity        True
# Dependents      False
# SurveyLength    False
# SurveyEase      False
# Length: 84, dtype: bool

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df['MainBranch']
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88875                       I am a developer by profession
# 88876                       I am a developer by profession
# 88877                       I am a developer by profession
# 88878                       I am a developer by profession
# 88882                       I am a developer by profession
# Name: MainBranch, Length: 88776, dtype: object

# %%
df.isnull().sum()
# Out:
# MainBranch      0
# Hobbyist        0
# OpenSourcer     0
# OpenSource      0
# Employment      0
#                ..
# Sexuality       0
# Ethnicity       3
# Dependents      0
# SurveyLength    0
# SurveyEase      0
# Length: 84, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# MainBranch      0
# Hobbyist        0
# OpenSourcer     0
# OpenSource      0
# Employment      0
#                ..
# Sexuality       0
# Ethnicity       0
# Dependents      0
# SurveyLength    0
# SurveyEase      0
# Length: 84, dtype: int64

# %%
df
# Out:
#                            MainBranch Hobbyist  \
# 6      I am a developer by profession       No
# 7         I code primarily as a hobby      Yes
# 8      I am a developer by profession      Yes
# 9      I am a developer by profession      Yes
# 10        I code primarily as a hobby      Yes
# ...                               ...      ...
# 88875  I am a developer by profession      Yes
# 88876  I am a developer by profession       No
# 88877  I am a developer by profession      Yes
# 88878  I am a developer by profession      Yes
# 88882  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 6                                                  Never
# 7                                Less than once per year
# 8                             Once a month or more often
# 9                             Once a month or more often
# 10                            Once a month or more often
# ...                                                  ...
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 6      The quality of OSS and closed source software ...
# 7      OSS is, on average, of HIGHER quality than pro...
# 8      The quality of OSS and closed source software ...
# 9      OSS is, on average, of HIGHER quality than pro...
# 10     The quality of OSS and closed source software ...
# ...                                                  ...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment              Country  \
# 6      Independent contractor, freelancer, or self-em...              Ukraine
# 7                     Not employed, but looking for work                India
# 8                                     Employed full-time          New Zealand
# 9                                     Employed full-time                India
# 10                                    Employed full-time  Antigua and Barbuda
# ...                                                  ...                  ...
# 88875                                 Employed part-time             Pakistan
# 88876                                 Employed full-time                Spain
# 88877                 Not employed, but looking for work        United States
# 88878             Not employed, and not looking for work               Canada
# 88882             Not employed, and not looking for work                Spain
#
#               Student                                            EdLevel  \
# 6                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                  No  Some college/university study without earning ...
# 9                  No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 10     Yes, full-time                          Primary/elementary school
# ...               ...                                                ...
# 88875  Yes, full-time  Secondary school (e.g. American high school, G...
# 88876              No  Secondary school (e.g. American high school, G...
# 88877              No  Some college/university study without earning ...
# 88878              No                          Primary/elementary school
# 88882  Yes, full-time                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 6      Another engineering discipline (ex. civil, ele...
# 7      Computer science, computer engineering, or sof...
# 8      Computer science, computer engineering, or sof...
# 9      Computer science, computer engineering, or sof...
# 10     Computer science, computer engineering, or sof...
# ...                                                  ...
# 88875  Computer science, computer engineering, or sof...
# 88876  Computer science, computer engineering, or sof...
# 88877  Computer science, computer engineering, or sof...
# 88878  Computer science, computer engineering, or sof...
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  ...  \
# 6      Taught yourself a new language, framework, or ...  ...
# 7      Taught yourself a new language, framework, or ...  ...
# 8      Taken an online course in programming or softw...  ...
# 9      Taken an online course in programming or softw...  ...
# 10                   Contributed to open source software  ...
# ...                                                  ...  ...
# 88875  Taken an online course in programming or softw...  ...
# 88876  Taught yourself a new language, framework, or ...  ...
# 88877  Taught yourself a new language, framework, or ...  ...
# 88878  Taught yourself a new language, framework, or ...  ...
# 88882  Taken an online course in programming or softw...  ...
#
#                                            WelcomeChange  \
# 6                  A lot more welcome now than last year
# 7                  A lot more welcome now than last year
# 8                Just as welcome now as I felt last year
# 9               Somewhat less welcome now than last year
# 10     Not applicable - I did not use Stack Overflow ...
# ...                                                  ...
# 88875  Not applicable - I did not use Stack Overflow ...
# 88876  Not applicable - I did not use Stack Overflow ...
# 88877            Just as welcome now as I felt last year
# 88878            Just as welcome now as I felt last year
# 88882           Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 6      Tech articles written by other developers;Indu...  42.0    Man    No
# 7      Tech articles written by other developers;Indu...  24.0    Man    No
# 8      Tech articles written by other developers;Indu...  23.0    Man    No
# 9      Tech articles written by other developers;Tech...  23.0    Man    No
# 10     Tech articles written by other developers;Tech...  22.0    Man   Yes
# ...                                                  ...   ...    ...   ...
# 88875       Courses on technologies you're interested in  25.0    Man    No
# 88876  Tech articles written by other developers;Indu...  40.0    Man    No
# 88877  Tech articles written by other developers;Indu...  40.0    Man    No
# 88878  Tech articles written by other developers;Tech...  40.0    Man    No
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                                              Sexuality  \
# 6                              Straight / Heterosexual
# 7                              Straight / Heterosexual
# 8                                             Bisexual
# 9                                             Bisexual
# 10     Bisexual;Gay or Lesbian;Straight / Heterosexual
# ...                                                ...
# 88875                          Straight / Heterosexual
# 88876                          Straight / Heterosexual
# 88877                          Straight / Heterosexual
# 88878                          Straight / Heterosexual
# 88882                          Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 6                           White or of European descent        Yes
# 7                           White or of European descent        Yes
# 8                           White or of European descent         No
# 9                           White or of European descent        Yes
# 10     Black or of African descent;East Asian;Hispani...         No
# ...                                                  ...        ...
# 88875                       White or of European descent        Yes
# 88876                       White or of European descent         No
# 88877                       White or of European descent         No
# 88878                       White or of European descent         No
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 6      Appropriate in length  Neither easy nor difficult
# 7      Appropriate in length  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 9                   Too long                   Difficult
# 10     Appropriate in length                        Easy
# ...                      ...                         ...
# 88875              Too short  Neither easy nor difficult
# 88876  Appropriate in length                        Easy
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
# 88882  Appropriate in length                        Easy
#
# [88770 rows x 84 columns]
